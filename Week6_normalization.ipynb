# %% [markdown]
# # Week6_Normalization

# %%
from google import colab
colab.drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Z.Chen/
# Out:
# /content/drive/MyDrive/Z.Chen

# %%
import pandas as pd

out = pd.read_pickle('./complete_df.csv')

# %%
out.head()
# Out:
#   RNA_chr  RNA_start    RNA_end Chromosome      Start        End  \
# 0    chr2   55026272   55026351       chr2   54082073   54082164
# 1   chr19   34277994   34278060      chr22   22327930   22328017
# 2    chr6  109264272  109264371       chr6  109264379  109264480
# 3   chr15   75892125   75892224       chr3  108451265  108451351
# 4   chr11  128504535  128504613      chr16   21775353   21775431
#
#   RNA_gene_name  DNA_gene_name
# 0          RTN4          ACYP2
# 1        GARRE1  CH17-264L24.2
# 2      CCDC162P       CCDC162P
# 3        UBE2Q2          MYH15
# 4          ETS1            NaN

# %%
def build_norm_one_file(df):
    # aggregate once
    edges = (df.groupby(["RNA_gene_name","DNA_gene_name"])
               .size().reset_index(name="count"))
    N = edges["count"].sum()
    edges["EPM"] = 1e6 * edges["count"] / N                 # library-size scaling
    edges["p_pair_given_RNA"] = edges["count"] / edges.groupby("RNA_gene_name")["count"].transform("sum")
    return edges, N

# %%
new_out = build_norm_one_file(out)[0]

# %%
new_out = build_norm_one_file(new_out)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3475184979.py in <cell line: 0>()
# ----> 1 new_out = build_norm_one_file(new_out)[0]
#
# /tmp/ipython-input-1945849598.py in build_norm_one_file(df)
#       1 def build_norm_one_file(df):
#       2     # aggregate once
# ----> 3     edges = (df.groupby(["RNA_gene_name","DNA_gene_name"])
#       4                .size().reset_index(name="count"))
#       5     N = edges["count"].sum()
#
# AttributeError: 'tuple' object has no attribute 'groupby'

# %%
new_out
# Out:
#          RNA_gene_name DNA_gene_name  count     EPM  p_pair_given_RNA
# 0              5S_rRNA       5S_rRNA      1  0.0304          0.017544
# 1              5S_rRNA           ABR      2  0.0608          0.035088
# 2              5S_rRNA        ADGRB2      1  0.0304          0.017544
# 3              5S_rRNA      ARHGAP39      1  0.0304          0.017544
# 4              5S_rRNA   BHLHE40-AS1      1  0.0304          0.017544
# ...                ...           ...    ...     ...               ...
# 10440245    yR211F11.2        MFSD11      1  0.0304          0.090909
# 10440246    yR211F11.2          PFKL      2  0.0608          0.181818
# 10440247    yR211F11.2          RGS3      3  0.0912          0.272727
# 10440248    yR211F11.2          TNS3      1  0.0304          0.090909
# 10440249    yR211F11.2    yR211F11.2      4  0.1216          0.363636
#
# [10440250 rows x 5 columns]

# %%
new_out[0]
# Out:
#          RNA_gene_name DNA_gene_name  count     EPM  p_pair_given_RNA
# 0              5S_rRNA       5S_rRNA      1  0.0304          0.017544
# 1              5S_rRNA           ABR      2  0.0608          0.035088
# 2              5S_rRNA        ADGRB2      1  0.0304          0.017544
# 3              5S_rRNA      ARHGAP39      1  0.0304          0.017544
# 4              5S_rRNA   BHLHE40-AS1      1  0.0304          0.017544
# ...                ...           ...    ...     ...               ...
# 10440245    yR211F11.2        MFSD11      1  0.0304          0.090909
# 10440246    yR211F11.2          PFKL      2  0.0608          0.181818
# 10440247    yR211F11.2          RGS3      3  0.0912          0.272727
# 10440248    yR211F11.2          TNS3      1  0.0304          0.090909
# 10440249    yR211F11.2    yR211F11.2      4  0.1216          0.363636
#
# [10440250 rows x 5 columns]
